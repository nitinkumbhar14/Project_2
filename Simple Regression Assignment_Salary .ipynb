# %%
import pandas as pd 
import seaborn as sns
import matplotlib as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### | Data Extraction |

# %%
def read_data():
    data = pd.read_csv("D:/Data Science/Tabelue/Salary_Data.csv")
    return data

# %%
data = read_data()
print(data.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# #### |Processing Data |

# %%
print("The number of Rows abd columns -", data.shape)
# Out:
# The number of Rows abd columns - (30, 2)

# %%
print("The data types", data.dtypes)
# Out:
# The data types YearsExperience    float64
# Salary             float64
# dtype: object

# %%
print("The number of Missing recoreds-")
data.isnull().sum()
# Out:
# The number of Missing recoreds-
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# #### |Explorarry Data Analysis |

# %%
print(data.describe())
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
sns.boxplot(x = data['YearsExperience'])
# Out:
# <Axes: xlabel='YearsExperience'>

# %%
sns.boxplot(x = data['Salary'])
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.scatterplot(x = data['YearsExperience'], y = data['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
data['YearsExperience'].plot()
data['Salary'].plot()
# Out:
# <Axes: >

# %% [markdown]
# #### |Sampling of data - Spliting the data Training & Testing |

# %%
from sklearn.model_selection import train_test_split

# %%
X = data['YearsExperience'].values.reshape(-1,1)
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y = data ['Salary'].values.reshape(-1,1)
y
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.2)

# %%
X_train.shape, X_test.shape
# Out:
# ((6, 1), (24, 1))

# %% [markdown]
# #### | Data Modeling |

# %%
model = LinearRegression()
model_train = model.fit(X_train, y_train)
print("Model training is completed")
# Out:
# Model training is completed

# %%
pred = model.predict(X_test)
pred
# Out:
# array([[ 47106.36771082],
#        [ 89639.49215869],
#        [ 92413.3915792 ],
#        [ 56352.69911253],
#        [123850.91834502],
#        [107207.52182194],
#        [ 73920.72877578],
#        [ 40633.93572963],
#        [ 63749.7642339 ],
#        [109981.42124245],
#        [ 75769.99505613],
#        [ 56352.69911253],
#        [ 81317.79389715],
#        [ 63749.7642339 ],
#        [ 45257.10143048],
#        [ 68372.92993476],
#        [102584.35612108],
#        [ 36935.40316894],
#        [ 82242.42703732],
#        [114604.58694331],
#        [115529.22008348],
#        [ 64674.39737407],
#        [ 53578.79969202],
#        [ 38784.66944928]])

# %%
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

# %%
r2_score(y_test,pred)
# Out:
# 0.9514090807880226

# %%
mean_squared_error(y_test,pred)
# Out:
# 36763915.21783393

# %%
sqrt(mean_squared_error(y_test,pred))
# Out:
# 6063.325425691246
